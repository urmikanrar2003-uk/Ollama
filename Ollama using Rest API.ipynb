# %% [markdown]
# # GENERATE USING OLLAMA LIBRARY

# %%
import ollama

response= ollama.generate(
    model="llama3.2:1b",
    prompt="Explain black holes simply"
)

print(response.response)
# Out:
# Imagine you have a super-powerful vacuum cleaner that sucks up everything around it, including light. That's kind of like what a black hole is.
#
# A black hole is a region in space where the gravitational pull is so strong that nothing, not even light, can escape once it gets too close. It's created when a massive star collapses in on itself and its gravity becomes so strong that it warps the fabric of spacetime around it.
#
# Think of spacetime as a trampoline. If you put a heavy object, like a bowling ball, on the trampoline, it will warp and curve, right? That's because the bowling ball is creating a gravitational field that warps the surrounding space.
#
# Now, imagine that instead of a bowling ball, we have an even more massive object, like a star. When this star collapses in on itself, its gravity becomes so strong that it creates a kind of cosmic sinkhole or vacuum. This sinkhole has such a strong gravity that nothing, not even light, can escape once it gets too close.
#
# The only way to tell if something is near a black hole is by looking at the way it moves around other objects in space. If an object is being pulled towards the black hole and doesn't seem to be affected by any gravitational forces, then it's probably getting sucked in. The faster it moves, the stronger the gravity.
#
# Black holes are really far away from us, so we don't have to worry about them causing harm on Earth. However, they can affect the motion of nearby objects, like planets and stars, which is why scientists use black hole detection techniques, such as observing how fast stars orbit around each other or looking for gravitational waves, to study these regions.
#
# In simple terms, a black hole is a region in space where gravity so strong that nothing escapes once it gets too close. It's created when a massive star collapses and its gravity becomes incredibly powerful.

# %% [markdown]
# # GENERATE USING REST API

# %%
import requests
import json

url = "http://localhost:11434/api/generate"

payload = {
    "model": "llama3.2:1b",
    "prompt": "Explain black holes simply"
}


response = requests.post(url, json=payload)

# %%
for i in response.iter_lines(): #ollama sends multiple json lines
    print(i)
# Out:
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.3988666Z","response":"Black","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.5163503Z","response":" holes","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.5266646Z","response":" are","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.5363588Z","response":" fascinating","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.5458102Z","response":" objects","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.555527Z","response":" in","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.5648431Z","response":" space","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.5748213Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.5850596Z","response":" can","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.5948326Z","response":" be","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.6047813Z","response":" explained","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.6146241Z","response":" simply","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.6245998Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.6342431Z","response":" Here","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.6443063Z","response":"\'s","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.6549512Z","response":" a","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.6650937Z","response":" basic","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.6746689Z","response":" understanding","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.6846223Z","response":":\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.6946082Z","response":"**","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.7042835Z","response":"What","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.7140084Z","response":" is","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.7236847Z","response":" a","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.7334312Z","response":" Black","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.7432995Z","response":" Hole","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.7531697Z","response":"?","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.762917Z","response":"**\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.7723373Z","response":"A","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.7826068Z","response":" black","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.7921553Z","response":" hole","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.8019262Z","response":" is","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.8118737Z","response":" a","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.8214156Z","response":" region","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.8308676Z","response":" in","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.8405967Z","response":" space","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.8500556Z","response":" where","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.8595218Z","response":" the","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.8693243Z","response":" gravitational","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.8786218Z","response":" pull","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.8871944Z","response":" is","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.8956673Z","response":" so","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.9041074Z","response":" strong","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.9129793Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.9218796Z","response":" nothing","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.9301787Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.9389938Z","response":" including","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.9478052Z","response":" light","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.9563185Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.9651511Z","response":" can","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.9736643Z","response":" escape","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.9818744Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:38.9912919Z","response":" It","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.0002342Z","response":"\'s","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.0089018Z","response":" created","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.0179141Z","response":" when","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.0267229Z","response":" a","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.0354601Z","response":" massive","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.0440261Z","response":" star","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.0525958Z","response":" collapses","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.0613969Z","response":" in","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.0700318Z","response":" on","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.0785158Z","response":" itself","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.0876808Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.0960617Z","response":" its","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.1050303Z","response":" gravity","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.1140591Z","response":" becomes","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.1230206Z","response":" so","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.1316948Z","response":" strong","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.1401901Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.1487257Z","response":" it","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.157456Z","response":" war","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.1660821Z","response":"ps","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.1748532Z","response":" the","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.1838402Z","response":" fabric","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.1927943Z","response":" of","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.2013239Z","response":" spac","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.2101888Z","response":"etime","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.2192049Z","response":" around","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.2280265Z","response":" it","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.2367232Z","response":".\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.2453627Z","response":"**","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.2542593Z","response":"How","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.2630023Z","response":" Does","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.2717454Z","response":" it","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.2809861Z","response":" Work","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.2894591Z","response":"?","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.298185Z","response":"**\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.3068458Z","response":"Imagine","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.3158484Z","response":" you","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.324424Z","response":"\'re","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.3331805Z","response":" standing","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.3422736Z","response":" near","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.3504852Z","response":" a","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-03-22T19:25:39.
,374,779,8147,430,433,34145,304,4205,430,66724,2288,3345,11,539,10923,433,311,12731,382,791,1486,315,912,471,2212,264,3776,14512,374,2663,279,330,3163,35174,1210,9843,2555,50535,279,1567,35174,11,433,596,31691,555,279,3776,14512,323,649,956,12731,13,578,71019,6958,374,779,3831,430,433,4208,1725,100108,4199,11,6968,264,19254,1405,4400,11,2737,3177,11,649,12731,382,334,3923,35800,729,311,34464,304,264,5348,52029,30,57277,2746,5030,477,25407,5334,2288,3345,311,264,3776,14512,11,433,596,13541,7119,279,4219,13,9843,433,50535,279,1567,35174,11,433,596,21830,10980,555,279,19428,71019,8603,13,578,5030,374,65262,323,41398,304,279,5216,315,279,24128,11,10671,62236,323,13967,67503,382,334,10445,527,5348,473,7298,44921,30,57277,14755,20349,1514,264,16996,3560,304,1057,8830,315,279,15861,13,2435,1520,603,4048,922,279,7865,315,11191,6302,323,1268,814,16681,449,1855,1023,13,3296,21630,3776,20349,11,14248,649,1101,8895,26793,1139,279,33472,315,8987,5540,11,279,18488,315,66017,11,323,279,7865,315,5030,1234,14560,4787,382,334,644,9170,20163,1131,57277,14755,20349,527,13918,304,3634,1405,24128,374,779,3831,430,4400,66209,13,2435,2351,3549,994,264,11191,6917,87458,304,389,5196,11,323,814,1520,603,3619,279,7865,315,11191,6302,323,279,15861,439,264,4459,13],"total_duration":5745804600,"load_duration":199951100,"prompt_eval_count":30,"prompt_eval_duration":1290051000,"eval_count":387,"eval_duration":3539510900}'

# %%
output= ""

for i in response.iter_lines():
    if i:
        data = json.loads(i.decode("utf-8"))
        if "response" in data:
            output+=data["response"]
        if data.get("done"):
            break


print(output)
# Out:
# Black holes are fascinating objects in space that can be explained simply. Here's a basic understanding:
#
# **What is a Black Hole?**
#
# A black hole is a region in space where the gravitational pull is so strong that nothing, including light, can escape. It's created when a massive star collapses in on itself and its gravity becomes so strong that it warps the fabric of spacetime around it.
#
# **How Does it Work?**
#
# Imagine you're standing near a huge vacuum cleaner that sucks up everything that gets too close. That's kind of what a black hole is – a region where gravity is so powerful that it pulls in anything that ventures too close, not allowing it to escape.
#
# The point of no return around a black hole is called the "event horizon." Once something crosses the event horizon, it's trapped by the black hole and can't escape. The gravitational pull is so strong that it warps spacetime, creating a boundary where nothing, including light, can escape.
#
# **What Happens to Matter in a Black Hole?**
#
# If matter or radiation gets too close to a black hole, it's pulled towards the center. Once it crosses the event horizon, it's torn apart by the intense gravitational forces. The matter is squeezed and stretched in the direction of the gravity, becoming distorted and ultimately disappearing.
#
# **Why are Black Holes Important?**
#
# Black holes play a crucial role in our understanding of the universe. They help us learn about the behavior of massive objects and how they interact with each other. By studying black holes, scientists can also gain insights into the origins of heavy elements, the formation of galaxies, and the behavior of matter under extreme conditions.
#
# **In Simple Terms...**
#
# Black holes are regions in space where gravity is so strong that nothing escapes. They're created when a massive star collapses in on itself, and they help us understand the behavior of massive objects and the universe as a whole.

# %% [markdown]
# # LIST USING OLLAMA LIBRARY

# %%
import ollama

models = ollama.list()


models   # models with details of models.
# Out:
# ListResponse(models=[Model(model='my-model:latest', modified_at=datetime.datetime(2026, 3, 23, 0, 41, 59, 174657, tzinfo=TzInfo(19800)), digest='b8b53cc75dcf6bbb8bd779119920f48343c4ccc2e31869a51a512f443ebd63dd', size=1321099145, details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='1.2B', quantization_level='Q8_0')), Model(model='qwen2.5:7b', modified_at=datetime.datetime(2026, 3, 23, 0, 8, 24, 993940, tzinfo=TzInfo(19800)), digest='845dbda0ea48ed749caafd9e6037047aa19acfcfd82e704d7ca97d631a0b697e', size=4683087332, details=ModelDetails(parent_model='', format='gguf', family='qwen2', families=['qwen2'], parameter_size='7.6B', quantization_level='Q4_K_M')), Model(model='moondream:latest', modified_at=datetime.datetime(2026, 3, 22, 22, 12, 25, 71275, tzinfo=TzInfo(19800)), digest='55fc3abd386771e5b5d1bbcc732f3c3f4df6e9f9f08f1131f9cc27ba2d1eec5b', size=1738451197, details=ModelDetails(parent_model='', format='gguf', family='phi2', families=['phi2', 'clip'], parameter_size='1B', quantization_level='Q4_0')), Model(model='llama3.2:1b', modified_at=datetime.datetime(2026, 3, 22, 20, 52, 45, 758398, tzinfo=TzInfo(19800)), digest='baf6a787fdffd633537aa2eb51cfd54cb93ff08e28040095462bb63daf552878', size=1321098329, details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='1.2B', quantization_level='Q8_0'))])

# %%
for model in models["models"]:  # iterate over models.
    print(model["model"])
# Out:
# my-model:latest
# qwen2.5:7b
# moondream:latest
# llama3.2:1b

# %% [markdown]
# # LIST USING REST API

# %%
import requests

url = "http://localhost:11434/api/tags"

r = requests.get(url)
data = r.json() #extracting the JSON data from the HTTP response and converting it into a Python object


data  # entire data.
# Out:
# {'models': [{'name': 'my-model:latest',
#    'model': 'my-model:latest',
#    'modified_at': '2026-03-23T00:41:59.1746571+05:30',
#    'size': 1321099145,
#    'digest': 'b8b53cc75dcf6bbb8bd779119920f48343c4ccc2e31869a51a512f443ebd63dd',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'llama',
#     'families': ['llama'],
#     'parameter_size': '1.2B',
#     'quantization_level': 'Q8_0'}},
#   {'name': 'qwen2.5:7b',
#    'model': 'qwen2.5:7b',
#    'modified_at': '2026-03-23T00:08:24.99394+05:30',
#    'size': 4683087332,
#    'digest': '845dbda0ea48ed749caafd9e6037047aa19acfcfd82e704d7ca97d631a0b697e',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'qwen2',
#     'families': ['qwen2'],
#     'parameter_size': '7.6B',
#     'quantization_level': 'Q4_K_M'}},
#   {'name': 'moondream:latest',
#    'model': 'moondream:latest',
#    'modified_at': '2026-03-22T22:12:25.0712756+05:30',
#    'size': 1738451197,
#    'digest': '55fc3abd386771e5b5d1bbcc732f3c3f4df6e9f9f08f1131f9cc27ba2d1eec5b',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'phi2',
#     'families': ['phi2', 'clip'],
#     'parameter_size': '1B',
#     'quantization_level': 'Q4_0'}},
#   {'name': 'llama3.2:1b',
#    'model': 'llama3.2:1b',
#    'modified_at': '2026-03-22T20:52:45.7583986+05:30',
#    'size': 1321098329,
#    'digest': 'baf6a787fdffd633537aa2eb51cfd54cb93ff08e28040095462bb63daf552878',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'llama',
#     'families': ['llama'],
#     'parameter_size': '1.2B',
#     'quantization_level': 'Q8_0'}}]}

# %%
for model in data["models"]:
    print(model["name"])
# Out:
# my-model:latest
# qwen2.5:7b
# moondream:latest
# llama3.2:1b
